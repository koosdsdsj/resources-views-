# %% [markdown]
# <a href="https://colab.research.google.com/github/koosdsdsj/resources-views-/blob/main/APD_YOLO11_TRAINING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 45.3 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolo11n.pt")

model.train(
    data="/content/drive/MyDrive/APD_SPLIT/dataset.yaml",
    epochs=150,
    imgsz=512,
    batch=8,
    name="apd_safe"
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.9 🚀 Python-3.12.12 torch-2.9.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# ...

# %%
# !pip install -U openmim

# !mim install mmengine

# !mim install "mmcv==2.1.0"

# !mim install "mmdet==3.3.0"
# Out:
# ...
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu124/torch2.6.0/index.html
# ...
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu124/torch2.6.0/index.html
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='download.openmmlab.com', port=443): Read timed out. (read timeout=15)")': /mmcv/dist/cu124/torch2.6.0/index.html
# ...
#   Using cached mmcv-2.1.0.tar.gz (471 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for mmcv: filename=mmcv-2.1.0-cp311-cp311-linux_x86_64.whl size=28808356 sha256=26593accdabbd79de2e5c60ca0e57b2f05e9fe804535350205295ff98d509972
#   Stored in directory: /root/.cache/pip/wheels/57/22/96/9bcbfeaa838c1b705a4b2ac082539767fbcc79fa07ec01abcd
# Successfully built mmcv
# ...
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu124/torch2.6.0/index.html
# ...
# Ignoring mmcv: markers 'extra == "mim"' don't match your environment
# ...
